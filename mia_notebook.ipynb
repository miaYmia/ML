# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
# Read file
df = pd.read_csv("/content/sample_data/price_cut.csv")
df = df.dropna(axis=1, how="all")

# %%
df
# Out:
#     Days  Cut
# 0     30    0
# 1     45    2
# 2     60    5
# 3     75    7
# 4     90   10
# 5    105   12
# 6    120   15
# 7    135   18
# 8    150   20
# 9    165   25
# 10   180   27
# 11   195   30
# 12   210   32
# 13   225   35
# 14   240   37
# 15   255   40
# 16   270   42
# 17   285   45
# 18   300   47
# 19   315   50

# %%
# Plot data
# @title Days on Market vs Price Cut (%)
# %matplotlib inline
plt.xlabel("Days on Market")
plt.ylabel("Price Cut %")
plt.scatter(df.Days, df.Cut, color='red', marker='+' )
plt.plot(df.Days, reg.predict(d[['Days']]), color='blue')

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(df[['Days']], df.Cut)
# Out:
# LinearRegression()

# %%
# Predict cut % for 50 days on market
reg.predict([[50]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.04736842])

# %%
# check coefficient
reg.coef_
# Out:
# -5.892481203007506

# %%
# check intercept
reg.intercept_
# Out:
# -5.892481203007506

# %%
# read a new file with only # of days on market
d = pd.read_csv("/content/sample_data/days.csv")
d = d.drop(columns=["Unnamed: 1"], errors="ignore")
d.head()
# Out:
#    Days
# 0    13
# 1    16
# 2    23
# 3    53
# 4    75

# %%
# make predictions
predictions = reg.predict(d)

d['prices'] = predictions

# %%
# Export predictions
d.to_csv("predictions.csv", index=False)
